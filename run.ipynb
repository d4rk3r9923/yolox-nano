# %%
# !conda create -n tfs python=3.9 -y

# %%
# !conda activate tfs

# %%
# !git clone https://github.com/d4rk3r9923/yolox-nano.git

# %%
# !cd "C:\\Users\\Admin\\Documents\\GitHub\\yolox-nano"

# %%
# !cd
# Out:
# c:\Users\Admin\Documents\GitHub\yolox-nano

# %%
# !conda install pytorch torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia

# %%
# !pip install -e .
# Out:
# Obtaining file:///C:/Users/Admin/Documents/GitHub/yolox-nano
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Attempting uninstall: yolox
#     Found existing installation: yolox 0.3.0
#     Uninstalling yolox-0.3.0:
#       Successfully uninstalled yolox-0.3.0
#   Running setup.py develop for yolox
# ...

# %%
# !python tools/train.py
# Out:
# ...
# 100%|##########| 74/74 [00:12<00:00,  5.69it/s]
#
# ...
# 100%|##########| 74/74 [00:09<00:00,  7.46it/s]
#
# ...
# 100%|##########| 74/74 [00:08<00:00,  8.38it/s]
#
# ...
# 100%|##########| 74/74 [00:09<00:00,  7.61it/s]
#
# ...
# 100%|##########| 74/74 [00:10<00:00,  7.39it/s]
#
# ...
# 100%|##########| 74/74 [00:10<00:00,  7.07it/s]
#
# ...
# 100%|##########| 74/74 [00:09<00:00,  7.55it/s]
#
# ...
# 100%|##########| 74/74 [00:10<00:00,  7.32it/s]
#
# ...
# 100%|##########| 74/74 [00:09<00:00,  7.79it/s]
#
# ...
# 100%|##########| 74/74 [00:09<00:00,  7.68it/s]
#
# ...
# 100%|##########| 74/74 [00:09<00:00,  7.42it/s]
#
# ...
# 100%|##########| 74/74 [00:09<00:00,  7.84it/s]
#
# ...
# 100%|##########| 74/74 [00:09<00:00,  7.65it/s]
#
# ...
# 100%|##########| 74/74 [00:09<00:00,  7.49it/s]
#
# ...
# 100%|##########| 74/74 [00:10<00:00,  7.24it/s]
#
# ...
# 100%|##########| 74/74 [00:09<00:00,  7.62it/s]
#
# ...
# 100%|##########| 74/74 [00:09<00:00,  7.83it/s]
#
# ...
# 100%|##########| 74/74 [00:09<00:00,  7.54it/s]
#
# ...
# 100%|##########| 74/74 [00:09<00:00,  7.78it/s]
#
# ...

# %%
# !python tools/eval.py --output_result="result.json"
# Out:
# ...
# 100%|##########| 10/10 [00:12<00:00,  1.23s/it]
# Average forward time: 7.77 ms, Average NMS time: 0.49 ms, Average inference time: 8.26 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.368
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.635
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.380
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.345
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.561
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.491
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.491
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.469
# ...

# %%
# !python tools/create_submission.py --exp_dir="YOLOX_outputs/tfs_nano" --output="submissions/submission_01.zip"
# Out:
# Zipping YOLOX_outputs/tfs_nano\best_ckpt.pth to submissions/submission_01.zip
# Zipping YOLOX_outputs/tfs_nano\tensorboard
#     > YOLOX_outputs/tfs_nano\tensorboard\events.out.tfevents.1690966974.PC.17012.0
# Created submission file submissions/submission_01.zip successfully!

# %%
# !git init
# Out:
# Reinitialized existing Git repository in C:/Users/Admin/Documents/GitHub/yolox-nano/.git/

# %%
# !git add .

# %%
# !git commit -m "Added files"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	run.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git branch -M main

# %%
# !git remote add origin https://github.com/d4rk3r9923/yolox-nano.git

# %%
# !git push -u origin main
